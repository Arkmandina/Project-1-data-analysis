# %%
import pandas as pd
import numpy as py

# %%
## Creating a path to the csv and read it into a Pandas DataFrame
precovid_ohio = "precovid_ohio2019.csv"
precovid_ohio_df = pd.read_csv(precovid_ohio)
precovid_ohio_df
# Out:
#                  business_id         name state_      city  stars  \
# 0     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 1     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 2     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 3     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 4     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# ...                      ...          ...    ...       ...    ...
# 5348  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5349  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5350  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5351  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
# 5352  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
#
#       review_count  is_open  \
# 0               16        0
# 1               16        0
# 2               16        0
# 3               16        0
# 4               16        0
# ...            ...      ...
# 5348            30        1
# 5349            30        1
# 5350            30        1
# 5351            19        1
# 5352            19        1
#
#                                              categories  customer_stars  \
# 0     Juice Bars & Smoothies, Vegan, Food, Restauran...               5
# 1     Juice Bars & Smoothies, Vegan, Food, Restauran...               5
# 2     Juice Bars & Smoothies, Vegan, Food, Restauran...               5
# 3     Juice Bars & Smoothies, Vegan, Food, Restauran...               4
# 4     Juice Bars & Smoothies, Vegan, Food, Restauran...               4
# ...                                                 ...             ...
# 5348               Soup, Salad, Sandwiches, Restaurants               4
# 5349               Soup, Salad, Sandwiches, Restaurants               4
# 5350               Soup, Salad, Sandwiches, Restaurants               4
# 5351               Sandwiches, Soup, Salad, Restaurants               5
# 5352               Sandwiches, Soup, Salad, Restaurants               5
#
#                 date_
# 0     1/20/2019 17:28
# 1      2/17/2019 2:45
# 2      8/7/2019 19:15
# 3      3/3/2019 20:32
# 4     5/24/2019 13:33
# ...               ...
# 5348   3/7/2019 18:25
# 5349   2/9/2019 21:57
# 5350   2/2/2019 14:18
# 5351  4/16/2019 11:26
# 5352   7/3/2019 13:14
#
# [5353 rows x 10 columns]

# %%
# reduce the dataframe to columns that are required
reduced_preohio =precovid_ohio_df[["business_id", "name", "state_", "city", "is_open", "categories"]]
reduced_preohio
# Out:
#                  business_id         name state_      city  is_open  \
# 0     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 1     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 2     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 3     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 4     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# ...                      ...          ...    ...       ...      ...
# 5348  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus        1
# 5349  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus        1
# 5350  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus        1
# 5351  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus        1
# 5352  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus        1
#
#                                              categories
# 0     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 1     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 2     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 3     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 4     Juice Bars & Smoothies, Vegan, Food, Restauran...
# ...                                                 ...
# 5348               Soup, Salad, Sandwiches, Restaurants
# 5349               Soup, Salad, Sandwiches, Restaurants
# 5350               Soup, Salad, Sandwiches, Restaurants
# 5351               Sandwiches, Soup, Salad, Restaurants
# 5352               Sandwiches, Soup, Salad, Restaurants
#
# [5353 rows x 6 columns]

# %%
# Drop the rows that do not contain business ID
red_preohio = reduced_preohio[reduced_preohio["business_id"] != "#NAME?"]
red_preohio
# Out:
#                  business_id         name state_      city  is_open  \
# 0     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 1     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 2     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 3     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# 4     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus        0
# ...                      ...          ...    ...       ...      ...
# 5348  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus        1
# 5349  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus        1
# 5350  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus        1
# 5351  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus        1
# 5352  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus        1
#
#                                              categories
# 0     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 1     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 2     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 3     Juice Bars & Smoothies, Vegan, Food, Restauran...
# 4     Juice Bars & Smoothies, Vegan, Food, Restauran...
# ...                                                 ...
# 5348               Soup, Salad, Sandwiches, Restaurants
# 5349               Soup, Salad, Sandwiches, Restaurants
# 5350               Soup, Salad, Sandwiches, Restaurants
# 5351               Sandwiches, Soup, Salad, Restaurants
# 5352               Sandwiches, Soup, Salad, Restaurants
#
# [5277 rows x 6 columns]

# %%
# Remove the duplicate business IDs
clean_preohio = red_preohio.drop_duplicates()
clean_preohio
# Out:
#                  business_id                         name state_         city  \
# 0     KPZHg7BGkyhLAZmUTIJnMw                  & Juice Co.     OH     Columbus
# 6     JqSL9fNnkwsxQkqGJyHJ2g             101 Beer Kitchen     OH  Westerville
# 73    n3sEf5PqRFHoJ_8TCynRPg            A Matter of Steak     OH     Hilliard
# 74    6zMk-He0XhowQu2p5pdtBg        Abner's Casual Dining     OH     Hilliard
# 79    IDlvMzb_9Prxzz2LK0Ww1Q                  Adobe Gilas     OH     Columbus
# ...                      ...                          ...    ...          ...
# 5319  J8BnOx3rJ9oO78KtF0K5OQ  Yoshi's Japanese Restaurant     OH       Dublin
# 5328  97q11wWWFqku1SOHZJx6gA                   Zest Juice     OH     Columbus
# 5330  NWjoZB068Mg18lYTI3AS2A                      Ziggy's     OH    Pataskala
# 5336  FyGavoQ1DdC3ZsjKAfxezA                        Zoup!     OH     Columbus
# 5351  IJVqt4PE0QKaqJ2VfBYBZg                        Zoup!     OH     Columbus
#
#       is_open                                         categories
# 0           0  Juice Bars & Smoothies, Vegan, Food, Restauran...
# 6           1  Gastropubs, Breakfast & Brunch, American (New)...
# 73          1  Sandwiches, Steakhouses, Cheesesteaks, Restaur...
# 74          1                Restaurants, American (Traditional)
# 79          1                               Mexican, Restaurants
# ...       ...                                                ...
# 5319        1                  Restaurants, Japanese, Sushi Bars
# 5328        1  Food, Acai Bowls, Juice Bars & Smoothies, Vege...
# 5330        1  Restaurants, Sports Bars, Bars, Nightlife, Ame...
# 5336        1               Soup, Salad, Sandwiches, Restaurants
# 5351        1               Sandwiches, Soup, Salad, Restaurants
#
# [472 rows x 6 columns]

# %%
## Creating a path to the csv and read it into a Pandas DataFrame
postcovid_ohio = "postcovid_ohio2020.csv"
postcovid_ohio_df = pd.read_csv(postcovid_ohio)
postcovid_ohio_df
# Out:
#                   business_id              name state_         city  stars  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 1      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 2      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 3      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 4      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# ...                       ...               ...    ...          ...    ...
# 19928  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19929  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19930  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19931  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19932  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
#
#        review_count  is_open  \
# 0               318        1
# 1               318        1
# 2               318        1
# 3               318        1
# 4               318        1
# ...             ...      ...
# 19928            52        1
# 19929            52        1
# 19930            52        1
# 19931            52        1
# 19932            52        1
#
#                                               categories  customer_stars  \
# 0      Gastropubs, Breakfast & Brunch, American (New)...               4
# 1      Gastropubs, Breakfast & Brunch, American (New)...               4
# 2      Gastropubs, Breakfast & Brunch, American (New)...               5
# 3      Gastropubs, Breakfast & Brunch, American (New)...               4
# 4      Gastropubs, Breakfast & Brunch, American (New)...               5
# ...                                                  ...             ...
# 19928      Sandwiches, Pizza, Chicken Wings, Restaurants               5
# 19929      Sandwiches, Pizza, Chicken Wings, Restaurants               5
# 19930      Sandwiches, Pizza, Chicken Wings, Restaurants               5
# 19931      Sandwiches, Pizza, Chicken Wings, Restaurants               5
# 19932      Sandwiches, Pizza, Chicken Wings, Restaurants               5
#
#                   date_
# 0        5/2/2020 21:57
# 1         8/2/2020 0:14
# 2       8/23/2020 17:40
# 3       5/12/2020 18:38
# 4       1/26/2020 21:19
# ...                 ...
# 19928   12/12/2020 1:33
# 19929    3/8/2020 20:03
# 19930   11/17/2020 2:24
# 19931  12/23/2020 22:11
# 19932    2/6/2020 18:44
#
# [19933 rows x 10 columns]

# %%
# reduce the dataframe to columns that are required
reduced_postohio =postcovid_ohio_df[["business_id", "name", "state_", "city", "is_open", "categories"]]
reduced_postohio
# Out:
#                   business_id              name state_         city  is_open  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 1      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 2      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 3      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 4      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# ...                       ...               ...    ...          ...      ...
# 19928  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19929  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19930  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19931  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19932  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
#
#                                               categories
# 0      Gastropubs, Breakfast & Brunch, American (New)...
# 1      Gastropubs, Breakfast & Brunch, American (New)...
# 2      Gastropubs, Breakfast & Brunch, American (New)...
# 3      Gastropubs, Breakfast & Brunch, American (New)...
# 4      Gastropubs, Breakfast & Brunch, American (New)...
# ...                                                  ...
# 19928      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19929      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19930      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19931      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19932      Sandwiches, Pizza, Chicken Wings, Restaurants
#
# [19933 rows x 6 columns]

# %%
# Drop the rows that do not contain business ID
red_postohio = reduced_postohio[reduced_postohio["business_id"] != "#NAME?"]
red_postohio
# Out:
#                   business_id              name state_         city  is_open  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 1      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 2      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 3      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# 4      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville        1
# ...                       ...               ...    ...          ...      ...
# 19928  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19929  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19930  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19931  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
# 19932  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard        1
#
#                                               categories
# 0      Gastropubs, Breakfast & Brunch, American (New)...
# 1      Gastropubs, Breakfast & Brunch, American (New)...
# 2      Gastropubs, Breakfast & Brunch, American (New)...
# 3      Gastropubs, Breakfast & Brunch, American (New)...
# 4      Gastropubs, Breakfast & Brunch, American (New)...
# ...                                                  ...
# 19928      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19929      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19930      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19931      Sandwiches, Pizza, Chicken Wings, Restaurants
# 19932      Sandwiches, Pizza, Chicken Wings, Restaurants
#
# [19613 rows x 6 columns]

# %%
# Remove the duplicate business IDs
clean_postohio = red_postohio.drop_duplicates()
clean_postohio
# Out:
#                   business_id                     name state_         city  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g         101 Beer Kitchen     OH  Westerville
# 35     fh-Guneo3jPLadG5rSsOWA         101 Beer Kitchen     OH      Gahanna
# 71     wCeUZf1sv5zu5dEU3a2tWg         101 Beer Kitchen     OH       Dublin
# 110    uTMksZ_1M8hoZb1l1q7vcQ                  12 West     OH     Delaware
# 117    XccJRhKG8zmdv8GUbE5RCg  14 Twenty Bar and Pizza     OH     Columbus
# ...                       ...                      ...    ...          ...
# 19910  Ko8iUGC-O9pMRnkV7TbCTA                    Zoup!     OH  Westerville
# 19912  fdIOgrUeeUWXSLd6RGlh9A                    Zoup!     OH     Columbus
# 19917  5fLgut04TxZ0zTs_oR8aqQ                    Zoup!     OH     Columbus
# 19919  n-MgG7TotpCGwz47bMN2dQ         Z's Asian Bistro     OH     Columbus
# 19922  wdkK-cgkYHvS8tp12uwjBQ             Zuko's Pizza     OH     Hilliard
#
#        is_open                                         categories
# 0            1  Gastropubs, Breakfast & Brunch, American (New)...
# 35           1  American (New), Breakfast & Brunch, Food, Beer...
# 71           1  Beer, Wine & Spirits, Restaurants, Breakfast &...
# 110          1                               Restaurants, Mexican
# 117          1  Bars, Nightlife, American (Traditional), Pubs,...
# ...        ...                                                ...
# 19910        1               Salad, Sandwiches, Restaurants, Soup
# 19912        1               Restaurants, Salad, Sandwiches, Soup
# 19917        1               Salad, Restaurants, Soup, Sandwiches
# 19919        1  Asian Fusion, Chinese, Thai, Restaurants, Japa...
# 19922        1      Sandwiches, Pizza, Chicken Wings, Restaurants
#
# [2497 rows x 6 columns]

# %%
## Creating a path to the csv and read it into a Pandas DataFrame
precovid_texas = "precovid_texas2019.csv"
precovid_texas_df = pd.read_csv(precovid_texas)
precovid_texas_df
# Out:
#                   business_id                name state_      city  stars  \
# 0      FwO183blfDg8g6sFv-NTsQ    15th Street Cafe     TX    Austin    3.5
# 1      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 2      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 3      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 4      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# ...                       ...                 ...    ...       ...    ...
# 17079  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17080  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17081  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17082  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17083  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
#
#        review_count  is_open  \
# 0                 9        1
# 1               641        1
# 2               641        1
# 3               641        1
# 4               641        1
# ...             ...      ...
# 17079            63        1
# 17080            63        1
# 17081            63        1
# 17082            63        1
# 17083            63        1
#
#                                               categories  customer_stars  \
# 0      Restaurants, Hotels & Travel, Event Planning &...               4
# 1      Food, Breakfast & Brunch, Thai, Restaurants, D...               5
# 2      Food, Breakfast & Brunch, Thai, Restaurants, D...               5
# 3      Food, Breakfast & Brunch, Thai, Restaurants, D...               5
# 4      Food, Breakfast & Brunch, Thai, Restaurants, D...               5
# ...                                                  ...             ...
# 17079             Gluten-Free, Pizza, Restaurants, Salad               5
# 17080             Gluten-Free, Pizza, Restaurants, Salad               5
# 17081             Gluten-Free, Pizza, Restaurants, Salad               5
# 17082             Gluten-Free, Pizza, Restaurants, Salad               5
# 17083             Gluten-Free, Pizza, Restaurants, Salad               5
#
#                   date_
# 0       7/23/2019 18:54
# 1       12/23/2019 0:53
# 2      10/27/2019 15:03
# 3      10/13/2019 20:54
# 4        12/8/2019 4:48
# ...                 ...
# 17079   12/30/2019 0:59
# 17080  12/18/2019 23:19
# 17081  12/30/2019 23:53
# 17082  12/28/2019 20:31
# 17083  12/21/2019 17:09
#
# [17084 rows x 10 columns]

# %%
# reduce the dataframe to columns that are required
reduced_pretexas =precovid_texas_df[["business_id", "name", "state_", "city", "is_open", "categories"]]
reduced_pretexas
# Out:
#                   business_id                name state_      city  is_open  \
# 0      FwO183blfDg8g6sFv-NTsQ    15th Street Cafe     TX    Austin        1
# 1      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# 2      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# 3      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# 4      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# ...                       ...                 ...    ...       ...      ...
# 17079  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17080  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17081  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17082  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17083  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
#
#                                               categories
# 0      Restaurants, Hotels & Travel, Event Planning &...
# 1      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 2      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 3      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 4      Food, Breakfast & Brunch, Thai, Restaurants, D...
# ...                                                  ...
# 17079             Gluten-Free, Pizza, Restaurants, Salad
# 17080             Gluten-Free, Pizza, Restaurants, Salad
# 17081             Gluten-Free, Pizza, Restaurants, Salad
# 17082             Gluten-Free, Pizza, Restaurants, Salad
# 17083             Gluten-Free, Pizza, Restaurants, Salad
#
# [17084 rows x 6 columns]

# %%
# Drop the rows that do not contain business ID
red_pretexas = reduced_pretexas[reduced_pretexas["business_id"] != "#NAME?"]
red_pretexas
# Out:
#                   business_id                name state_      city  is_open  \
# 0      FwO183blfDg8g6sFv-NTsQ    15th Street Cafe     TX    Austin        1
# 1      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# 2      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# 3      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# 4      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin        1
# ...                       ...                 ...    ...       ...      ...
# 17079  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17080  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17081  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17082  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
# 17083  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave        1
#
#                                               categories
# 0      Restaurants, Hotels & Travel, Event Planning &...
# 1      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 2      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 3      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 4      Food, Breakfast & Brunch, Thai, Restaurants, D...
# ...                                                  ...
# 17079             Gluten-Free, Pizza, Restaurants, Salad
# 17080             Gluten-Free, Pizza, Restaurants, Salad
# 17081             Gluten-Free, Pizza, Restaurants, Salad
# 17082             Gluten-Free, Pizza, Restaurants, Salad
# 17083             Gluten-Free, Pizza, Restaurants, Salad
#
# [16765 rows x 6 columns]

# %%
# Remove the duplicate business IDs
clean_pretexas = red_pretexas.drop_duplicates()
clean_pretexas
# Out:
#                   business_id                  name state_      city  is_open  \
# 0      FwO183blfDg8g6sFv-NTsQ      15th Street Cafe     TX    Austin        1
# 1      Rba9Ol4jnTiov6_iAuoF5g     1618 Asian Fusion     TX    Austin        1
# 158    3sAFxULUcjyPzj3G7YPwiA      3 Train Pizzeria     TX    Austin        0
# 160    ff9xAuZ3-9iljMexfkf3yA      34th Street Cafe     TX    Austin        1
# 165    cXPM7gRVNhAVBk_QGE4Nmg             360 Pizza     TX    Austin        0
# ...                       ...                   ...    ...       ...      ...
# 17047  fQ4-MQu9PH66Wol8wKR_tQ                Yanagi     TX    Austin        1
# 17061  Pkp824mx2LL93TqKOdfMyQ  Yoree Korean Cuisine     TX    Austin        1
# 17066  KAv9I6DKsMCDZveyLEiBoA          Zaviya Grill     TX    Austin        1
# 17075  Ist18QqY3lFq-_wDzj3WyA                zpizza     TX    Austin        0
# 17076  sXgzgNe7YJO1A_86EKUyCw    ZZA Pizza +Â Salad     TX  Bee Cave        1
#
#                                               categories
# 0      Restaurants, Hotels & Travel, Event Planning &...
# 1      Food, Breakfast & Brunch, Thai, Restaurants, D...
# 158                                   Restaurants, Pizza
# 160    Event Planning & Services, Caterers, Restauran...
# 165    Sandwiches, Desserts, Beer, Wine & Spirits, Re...
# ...                                                  ...
# 17047                  Japanese, Sushi Bars, Restaurants
# 17061                 Korean, Restaurants, Soup, Seafood
# 17066  Vegetarian, Restaurants, Halal, Buffets, India...
# 17075  Vegan, Pizza, Gluten-Free, Restaurants, Medite...
# 17076             Gluten-Free, Pizza, Restaurants, Salad
#
# [497 rows x 6 columns]

# %%
## Creating a path to the csv and read it into a Pandas DataFrame
postcovid_texas = "postcovid_texas2020.csv"
postcovid_texas_df = pd.read_csv(postcovid_texas,encoding='latin-1')
postcovid_texas_df
# Out:
#                   business_id                name state_      city  stars  \
# 0      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 1      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 2      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 3      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 4      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# ...                       ...                 ...    ...       ...    ...
# 46575  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46576  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46577  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46578  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46579  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
#
#        review_count  is_open  \
# 0               256        1
# 1               256        1
# 2               256        1
# 3               256        1
# 4               256        1
# ...             ...      ...
# 46575            63        1
# 46576            63        1
# 46577            63        1
# 46578            63        1
# 46579            63        1
#
#                                               categories  customer_stars  \
# 0      Bubble Tea, Restaurants, Coffee & Tea, Asian F...               3
# 1      Bubble Tea, Restaurants, Coffee & Tea, Asian F...               3
# 2      Bubble Tea, Restaurants, Coffee & Tea, Asian F...               5
# 3      Bubble Tea, Restaurants, Coffee & Tea, Asian F...               5
# 4      Bubble Tea, Restaurants, Coffee & Tea, Asian F...               5
# ...                                                  ...             ...
# 46575             Gluten-Free, Pizza, Restaurants, Salad               3
# 46576             Gluten-Free, Pizza, Restaurants, Salad               5
# 46577             Gluten-Free, Pizza, Restaurants, Salad               5
# 46578             Gluten-Free, Pizza, Restaurants, Salad               5
# 46579             Gluten-Free, Pizza, Restaurants, Salad               5
#
#                  date_
# 0       7/16/2020 4:36
# 1      1/23/2020 16:50
# 2      5/12/2020 23:50
# 3       5/7/2020 21:34
# 4       8/5/2020 21:21
# ...                ...
# 46575  8/21/2020 22:58
# 46576   5/4/2020 23:38
# 46577   7/4/2020 21:37
# 46578  1/31/2020 20:38
# 46579  12/5/2020 14:27
#
# [46580 rows x 10 columns]

# %%
# reduce the dataframe to columns that are required
reduced_posttexas =postcovid_texas_df[["business_id", "name", "state_", "city", "is_open", "categories"]]
reduced_posttexas
# Out:
#                   business_id                name state_      city  is_open  \
# 0      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 1      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 2      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 3      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 4      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# ...                       ...                 ...    ...       ...      ...
# 46575  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46576  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46577  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46578  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46579  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
#
#                                               categories
# 0      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 1      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 2      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 3      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 4      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# ...                                                  ...
# 46575             Gluten-Free, Pizza, Restaurants, Salad
# 46576             Gluten-Free, Pizza, Restaurants, Salad
# 46577             Gluten-Free, Pizza, Restaurants, Salad
# 46578             Gluten-Free, Pizza, Restaurants, Salad
# 46579             Gluten-Free, Pizza, Restaurants, Salad
#
# [46580 rows x 6 columns]

# %%
# Drop the rows that do not contain business ID
red_posttexas = reduced_posttexas[reduced_posttexas["business_id"] != "#NAME?"]
red_posttexas
# Out:
#                   business_id                name state_      city  is_open  \
# 0      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 1      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 2      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 3      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# 4      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin        1
# ...                       ...                 ...    ...       ...      ...
# 46575  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46576  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46577  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46578  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
# 46579  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave        1
#
#                                               categories
# 0      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 1      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 2      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 3      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 4      Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# ...                                                  ...
# 46575             Gluten-Free, Pizza, Restaurants, Salad
# 46576             Gluten-Free, Pizza, Restaurants, Salad
# 46577             Gluten-Free, Pizza, Restaurants, Salad
# 46578             Gluten-Free, Pizza, Restaurants, Salad
# 46579             Gluten-Free, Pizza, Restaurants, Salad
#
# [45790 rows x 6 columns]

# %%
# Remove the duplicate business IDs
clean_posttexas = red_posttexas.drop_duplicates()
clean_posttexas
# Out:
#                   business_id                        name state_      city  \
# 0      6uSPLo9R0vxtJxPIhsMSMg              101 By Teahaus     TX    Austin
# 63     Rba9Ol4jnTiov6_iAuoF5g           1618 Asian Fusion     TX    Austin
# 522    cmFvz2m5NIyq9PAo4-qCGA            1776 Cheesesteak     TX    Austin
# 537    hpAOH8cmY5WHjnl8jGQ1dA          1886 Cafe & Bakery     TX    Austin
# 564    YW8FLZzjRwBo2mYTuE4PYg                20Pho7Austin     TX    Austin
# ...                       ...                         ...    ...       ...
# 46458  pp73b2zGEwRbwSgYYvB2Dg   Z'Tejas - Austin 6 STREET     TX    Austin
# 46483  TFylNfp1RM0NuUQopvsyIA  Z-Tejas Southwestern Grill     TX    Austin
# 46505  _VcTzv8XUhfanoxiUfqPlQ        Zucchini Kill Bakery     TX    Austin
# 46527  iFofOanM-8rT21M0SHNjoA  Zuzu Handmade Mexican Food     TX    Austin
# 46534  sXgzgNe7YJO1A_86EKUyCw          ZZA Pizza +?ÿSalad     TX  Bee Cave
#
#        is_open                                         categories
# 0            1  Bubble Tea, Restaurants, Coffee & Tea, Asian F...
# 63           1  Food, Breakfast & Brunch, Thai, Restaurants, D...
# 522          1  Cheesesteaks, Sandwiches, Restaurants, Food, A...
# 537          1  Restaurants, Bakeries, American (Traditional),...
# 564          1  Food, Vietnamese, French, Restaurants, Food Tr...
# ...        ...                                                ...
# 46458        1     Tex-Mex, Nightlife, Bars, Restaurants, Mexican
# 46483        1  American (New), Tex-Mex, Bars, Restaurants, Me...
# 46505        1  Food, Vegan, Gluten-Free, Bakeries, Cupcakes, ...
# 46527        1  Mexican, Caterers, Restaurants, Event Planning...
# 46534        1             Gluten-Free, Pizza, Restaurants, Salad
#
# [2915 rows x 6 columns]

# %%
merged_texas = pd.merge(clean_pretexas, clean_posttexas, how="outer", on="business_id").fillna(0)
merged_texas["is_open_x"] = merged_texas["is_open_x"].astype('int64')
merged_texas["is_open_y"] = merged_texas["is_open_y"].astype('int64')
merged_texas
# Out:
#                  business_id             name_x state__x  city_x  is_open_x  \
# 0     FwO183blfDg8g6sFv-NTsQ   15th Street Cafe       TX  Austin          1
# 1     Rba9Ol4jnTiov6_iAuoF5g  1618 Asian Fusion       TX  Austin          1
# 2     3sAFxULUcjyPzj3G7YPwiA   3 Train Pizzeria       TX  Austin          0
# 3     ff9xAuZ3-9iljMexfkf3yA   34th Street Cafe       TX  Austin          1
# 4     cXPM7gRVNhAVBk_QGE4Nmg          360 Pizza       TX  Austin          0
# ...                      ...                ...      ...     ...        ...
# 2984  Un6ARWGLtcoA3vCsVathEA                  0        0       0          0
# 2985  pp73b2zGEwRbwSgYYvB2Dg                  0        0       0          0
# 2986  TFylNfp1RM0NuUQopvsyIA                  0        0       0          0
# 2987  _VcTzv8XUhfanoxiUfqPlQ                  0        0       0          0
# 2988  iFofOanM-8rT21M0SHNjoA                  0        0       0          0
#
#                                            categories_x  \
# 0     Restaurants, Hotels & Travel, Event Planning &...
# 1     Food, Breakfast & Brunch, Thai, Restaurants, D...
# 2                                    Restaurants, Pizza
# 3     Event Planning & Services, Caterers, Restauran...
# 4     Sandwiches, Desserts, Beer, Wine & Spirits, Re...
# ...                                                 ...
# 2984                                                  0
# 2985                                                  0
# 2986                                                  0
# 2987                                                  0
# 2988                                                  0
#
#                           name_y state__y  city_y  is_open_y  \
# 0                              0        0       0          0
# 1              1618 Asian Fusion       TX  Austin          1
# 2                              0        0       0          0
# 3               34th Street Cafe       TX  Austin          1
# 4                      360 Pizza       TX  Austin          0
# ...                          ...      ...     ...        ...
# 2984                Zoes Kitchen       TX  Austin          0
# 2985   Z'Tejas - Austin 6 STREET       TX  Austin          1
# 2986  Z-Tejas Southwestern Grill       TX  Austin          1
# 2987        Zucchini Kill Bakery       TX  Austin          1
# 2988  Zuzu Handmade Mexican Food       TX  Austin          1
#
#                                            categories_y
# 0                                                     0
# 1     Food, Breakfast & Brunch, Thai, Restaurants, D...
# 2                                                     0
# 3     Event Planning & Services, Caterers, Restauran...
# 4     Sandwiches, Desserts, Beer, Wine & Spirits, Re...
# ...                                                 ...
# 2984  Restaurants, Mediterranean, Sandwiches, Kebab,...
# 2985     Tex-Mex, Nightlife, Bars, Restaurants, Mexican
# 2986  American (New), Tex-Mex, Bars, Restaurants, Me...
# 2987  Food, Vegan, Gluten-Free, Bakeries, Cupcakes, ...
# 2988  Mexican, Caterers, Restaurants, Event Planning...
#
# [2989 rows x 11 columns]

# %%
# Filter restaurants in texas that were open pre covid and are open post covid
prepost_open_texas = merged_texas[(merged_texas["is_open_x"] == 1) & (merged_texas["is_open_y"] == 1)]
prepost_open_texas   
# Observation: 383 restaurants survived during the pandemic
# Out:
#                 business_id                name_x state__x    city_x  \
# 1    Rba9Ol4jnTiov6_iAuoF5g     1618 Asian Fusion       TX    Austin
# 3    ff9xAuZ3-9iljMexfkf3yA      34th Street Cafe       TX    Austin
# 7    knOY5Nt5GlmIxAadPlirvQ         Ã±oÃ±os tacos       TX    Austin
# 10   PkmsrSoqd6t8iCnNopEsUw           Ah Sing Den       TX    Austin
# 11   Z5Z3lzVfeuY4RShRdQiTzA           Alta's Cafe       TX    Austin
# ..                      ...                   ...      ...       ...
# 491  Duo_6gTM6fITah0CwG3s6Q  Yahala Hookah Lounge       TX    Austin
# 492  fQ4-MQu9PH66Wol8wKR_tQ                Yanagi       TX    Austin
# 493  Pkp824mx2LL93TqKOdfMyQ  Yoree Korean Cuisine       TX    Austin
# 494  KAv9I6DKsMCDZveyLEiBoA          Zaviya Grill       TX    Austin
# 496  sXgzgNe7YJO1A_86EKUyCw    ZZA Pizza +Â Salad       TX  Bee Cave
#
#      is_open_x                                       categories_x  \
# 1            1  Food, Breakfast & Brunch, Thai, Restaurants, D...
# 3            1  Event Planning & Services, Caterers, Restauran...
# 7            1  Restaurants, Breakfast & Brunch, Tex-Mex, Mexican
# 10           1  Bars, Pan Asian, Restaurants, Asian Fusion, Co...
# 11           1  Wine Bars, Restaurants, Food, Coffee & Tea, Be...
# ..         ...                                                ...
# 491          1  Tobacco Shops, Middle Eastern, Bars, Restauran...
# 492          1                  Japanese, Sushi Bars, Restaurants
# 493          1                 Korean, Restaurants, Soup, Seafood
# 494          1  Vegetarian, Restaurants, Halal, Buffets, India...
# 496          1             Gluten-Free, Pizza, Restaurants, Salad
#
#                    name_y state__y    city_y  is_open_y  \
# 1       1618 Asian Fusion       TX    Austin          1
# 3        34th Street Cafe       TX    Austin          1
# 7           ?ño?ños tacos       TX    Austin          1
# 10            Ah Sing Den       TX    Austin          1
# 11            Alta's Cafe       TX    Austin          1
# ..                    ...      ...       ...        ...
# 491  Yahala Hookah Lounge       TX    Austin          1
# 492                Yanagi       TX    Austin          1
# 493  Yoree Korean Cuisine       TX    Austin          1
# 494          Zaviya Grill       TX    Austin          1
# 496    ZZA Pizza +?ÿSalad       TX  Bee Cave          1
#
#                                           categories_y
# 1    Food, Breakfast & Brunch, Thai, Restaurants, D...
# 3    Event Planning & Services, Caterers, Restauran...
# 7    Restaurants, Breakfast & Brunch, Tex-Mex, Mexican
# 10   Bars, Pan Asian, Restaurants, Asian Fusion, Co...
# 11   Wine Bars, Restaurants, Food, Coffee & Tea, Be...
# ..                                                 ...
# 491  Tobacco Shops, Middle Eastern, Bars, Restauran...
# 492                  Japanese, Sushi Bars, Restaurants
# 493                 Korean, Restaurants, Soup, Seafood
# 494  Vegetarian, Restaurants, Halal, Buffets, India...
# 496             Gluten-Free, Pizza, Restaurants, Salad
#
# [383 rows x 11 columns]

# %%
prepost_close_texas = merged_texas[(merged_texas["is_open_x"] == 0) & (merged_texas["is_open_y"] == 0)]
prepost_close_texas
# Out:
#                  business_id                     name_x state__x       city_x  \
# 2     3sAFxULUcjyPzj3G7YPwiA           3 Train Pizzeria       TX       Austin
# 4     cXPM7gRVNhAVBk_QGE4Nmg                  360 Pizza       TX       Austin
# 5     bUzFOiNj1y5xxazKo35CUA                  360 Pizza       TX  Rollingwood
# 6     YPkzxHKbnTWuvPcwVI7ulw  827 Rays Kitchen + Cellar       TX       Austin
# 8     0oOZXIRBem6ZK-k-VsTKJw               Afghan Halal       TX       Austin
# ...                      ...                        ...      ...          ...
# 2925  CYAkYUjKTycDER_l80qP0Q                          0        0            0
# 2942  _ETfvs2YhQYvpyDRU7_iJQ                          0        0            0
# 2976  eO7965WkYeMyA1Z9yoD--A                          0        0            0
# 2977  PqdSkcG_kN4OtaFaiRWU_Q                          0        0            0
# 2984  Un6ARWGLtcoA3vCsVathEA                          0        0            0
#
#       is_open_x                                       categories_x  \
# 2             0                                 Restaurants, Pizza
# 4             0  Sandwiches, Desserts, Beer, Wine & Spirits, Re...
# 5             0  Gluten-Free, Pizza, Desserts, Food, Sandwiches...
# 6             0  Bars, Nightlife, Seafood, Restaurants, Wine Ba...
# 8             0  Restaurants, Afghan, Halal, Mediterranean, Foo...
# ...         ...                                                ...
# 2925          0                                                  0
# 2942          0                                                  0
# 2976          0                                                  0
# 2977          0                                                  0
# 2984          0                                                  0
#
#                               name_y state__y       city_y  is_open_y  \
# 2                                  0        0            0          0
# 4                          360 Pizza       TX       Austin          0
# 5                          360 Pizza       TX  Rollingwood          0
# 6                                  0        0            0          0
# 8                       Afghan Halal       TX       Austin          0
# ...                              ...      ...          ...        ...
# 2925  Which Wich Superior Sandwiches       TX       Austin          0
# 2942            Wings To Go - Austin       TX       Austin          0
# 2976                 Yummy Thai Food       TX       Austin          0
# 2977                            Yuyo       TX       Austin          0
# 2984                    Zoes Kitchen       TX       Austin          0
#
#                                            categories_y
# 2                                                     0
# 4     Sandwiches, Desserts, Beer, Wine & Spirits, Re...
# 5     Gluten-Free, Pizza, Desserts, Food, Sandwiches...
# 6                                                     0
# 8     Restaurants, Afghan, Halal, Mediterranean, Foo...
# ...                                                 ...
# 2925  Restaurants, Event Planning & Services, Fast F...
# 2942                  Salad, Chicken Wings, Restaurants
# 2976  Thai, Restaurants, Food, Asian Fusion, Food Tr...
# 2977         Vegetarian, Peruvian, Restaurants, Seafood
# 2984  Restaurants, Mediterranean, Sandwiches, Kebab,...
#
# [270 rows x 11 columns]

# %%
merged_ohio = pd.merge(clean_preohio, clean_postohio, how="outer", on="business_id").fillna(0)
merged_ohio
# Out:
#                  business_id                 name_x state__x       city_x  \
# 0     KPZHg7BGkyhLAZmUTIJnMw            & Juice Co.       OH     Columbus
# 1     JqSL9fNnkwsxQkqGJyHJ2g       101 Beer Kitchen       OH  Westerville
# 2     n3sEf5PqRFHoJ_8TCynRPg      A Matter of Steak       OH     Hilliard
# 3     6zMk-He0XhowQu2p5pdtBg  Abner's Casual Dining       OH     Hilliard
# 4     IDlvMzb_9Prxzz2LK0Ww1Q            Adobe Gilas       OH     Columbus
# ...                      ...                    ...      ...          ...
# 2588  Ko8iUGC-O9pMRnkV7TbCTA                      0        0            0
# 2589  fdIOgrUeeUWXSLd6RGlh9A                      0        0            0
# 2590  5fLgut04TxZ0zTs_oR8aqQ                      0        0            0
# 2591  n-MgG7TotpCGwz47bMN2dQ                      0        0            0
# 2592  wdkK-cgkYHvS8tp12uwjBQ                      0        0            0
#
#       is_open_x                                       categories_x  \
# 0           0.0  Juice Bars & Smoothies, Vegan, Food, Restauran...
# 1           1.0  Gastropubs, Breakfast & Brunch, American (New)...
# 2           1.0  Sandwiches, Steakhouses, Cheesesteaks, Restaur...
# 3           1.0                Restaurants, American (Traditional)
# 4           1.0                               Mexican, Restaurants
# ...         ...                                                ...
# 2588        0.0                                                  0
# 2589        0.0                                                  0
# 2590        0.0                                                  0
# 2591        0.0                                                  0
# 2592        0.0                                                  0
#
#                      name_y state__y       city_y  is_open_y  \
# 0                         0        0            0        0.0
# 1          101 Beer Kitchen       OH  Westerville        1.0
# 2         A Matter of Steak       OH     Hilliard        1.0
# 3     Abner's Casual Dining       OH     Hilliard        1.0
# 4               Adobe Gilas       OH     Columbus        1.0
# ...                     ...      ...          ...        ...
# 2588                  Zoup!       OH  Westerville        1.0
# 2589                  Zoup!       OH     Columbus        1.0
# 2590                  Zoup!       OH     Columbus        1.0
# 2591       Z's Asian Bistro       OH     Columbus        1.0
# 2592           Zuko's Pizza       OH     Hilliard        1.0
#
#                                            categories_y
# 0                                                     0
# 1     Gastropubs, Breakfast & Brunch, American (New)...
# 2     Sandwiches, Steakhouses, Cheesesteaks, Restaur...
# 3                   Restaurants, American (Traditional)
# 4                                  Mexican, Restaurants
# ...                                                 ...
# 2588               Salad, Sandwiches, Restaurants, Soup
# 2589               Restaurants, Salad, Sandwiches, Soup
# 2590               Salad, Restaurants, Soup, Sandwiches
# 2591  Asian Fusion, Chinese, Thai, Restaurants, Japa...
# 2592      Sandwiches, Pizza, Chicken Wings, Restaurants
#
# [2593 rows x 11 columns]
